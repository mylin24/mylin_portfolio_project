# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\fpt kinh mon\\Downloads\\Walmart_Sales.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %% [markdown]
# ### Data Cleaning ###

# %%
df = df.sort_values(by=['Store','Date'])
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df['Date'] = df['Date'].dt.strftime('%m-%d-%Y')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  02-05-2010    1643690.90             0        42.31       2.572
# 1         1  02-12-2010    1641957.44             1        38.51       2.548
# 2         1  02-19-2010    1611968.17             0        39.93       2.514
# 3         1  02-26-2010    1409727.59             0        46.63       2.561
# 4         1  03-05-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  09-28-2012     713173.95             0        64.88       3.997
# 6431     45  10-05-2012     733455.07             0        64.89       3.985
# 6432     45  10-12-2012     734464.36             0        54.47       4.000
# 6433     45  10-19-2012     718125.53             0        56.47       3.969
# 6434     45  10-26-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df['Weekly_Sales'] = df['Weekly_Sales'].round(2)
df['Temperature'] = df['Temperature'].round(0).astype(int)
df['Fuel_Price'] = df['Fuel_Price'].round(2)
df['CPI'] = df['CPI'].round(3)
df['Unemployment'] = df['Unemployment'].round(3)
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  02-05-2010    1643690.90             0           42        2.57
# 1         1  02-12-2010    1641957.44             1           38        2.55
# 2         1  02-19-2010    1611968.17             0           40        2.51
# 3         1  02-26-2010    1409727.59             0           47        2.56
# 4         1  03-05-2010    1554806.68             0           46        2.62
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  09-28-2012     713173.95             0           65        4.00
# 6431     45  10-05-2012     733455.07             0           65        3.98
# 6432     45  10-12-2012     734464.36             0           54        4.00
# 6433     45  10-19-2012     718125.53             0           56        3.97
# 6434     45  10-26-2012     760281.43             0           59        3.88
#
#           CPI  Unemployment
# ...

# %%
missing_data = df.isnull().sum()
missing_data
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.to_csv('Walmart_Sales_Clean.csv', index=False)

# %% [markdown]
# ### Which holidays affect weekly sales the most? ###

# %%
avg_sales_by_holiday = df.groupby('Holiday_Flag')['Weekly_Sales'].mean()
avg_sales_by_holiday
# Out:
# Holiday_Flag
# 0    1.041256e+06
# 1    1.122888e+06
# Name: Weekly_Sales, dtype: float64

# %%
total_sales_by_holiday = df.groupby('Holiday_Flag')['Weekly_Sales'].sum()
total_sales_by_holiday
# Out:
# Holiday_Flag
# 0    6.231919e+09
# 1    5.052996e+08
# Name: Weekly_Sales, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.barplot(x=avg_sales_by_holiday.index, y=avg_sales_by_holiday.values, palette='viridis')
plt.title('Average Weekly Sales by Holiday Flag')
plt.xlabel('Holiday_Flag')
plt.ylabel('Avg_Weekly_Sales')
plt.xticks([0, 1], ['Not Holiday', 'Holiday'])
plt.show()

# %%
sns.barplot(x=total_sales_by_holiday.index, y=total_sales_by_holiday.values,palette='viridis')
plt.title('Total Weekly Sales by Holiday Flag')
plt.xlabel('Holiday_Flag')
plt.ylabel('Total_Week_Sales')
plt.xticks([0,1],['Not Holiday','Holiday'])
plt.show()

# %% [raw]
# From the above charts, we can see an increase in average weekly sales on holiday. However, overall total sales on holiday are lower than sales revenue on weekdays. This is due to the limited number of holidays each year, which reduces the overall total

# %%
# top 20 sales
Top_20_Sales= df.sort_values(by='Weekly_Sales',ascending=False).head(20)
Top_20_Sales
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14  12-24-2010    3818686.45             0           31        3.14
# 2763     20  12-24-2010    3766687.43             0           25        3.14
# 1333     10  12-24-2010    3749057.69             0           57        3.24
# 527       4  12-23-2011    3676388.98             0           36        3.10
# 1762     13  12-24-2010    3595903.20             0           35        2.85
# 1814     13  12-23-2011    3556766.03             0           25        3.19
# 2815     20  12-23-2011    3555371.03             0           40        3.39
# 475       4  12-24-2010    3526713.39             0           43        2.89
# 1385     10  12-23-2011    3487986.89             0           48        3.54
# 189       2  12-24-2010    3436007.68             0           50        2.89
# 1957     14  12-23-2011    3369068.99             0           42        3.39
# ...

# %%
import plotly.express as px
fig = px.scatter(Top_20_Sales, x="Date", y="Weekly_Sales",color='Store',size='Weekly_Sales',title='Top 20 Weekly Sales by Store Over Time')
fig.show()

# %% [markdown]
# From the above plot we can see that the highest sales lies in stores occur on December 23-24, which is Christmas Eve. Additionally, there are noticeable spikes around November 25 and 26 .

# %% [markdown]
# ### Which stores have the lowest and highest unemployment rates?  ###

# %%
min_unemployment = df.groupby('Store')['Unemployment'].min()
max_unemployment = df.groupby('Store')['Unemployment'].max()
# Stores have the lowest and highest unemployment rate
store_with_min_employment= min_unemployment.idxmin(),  min_unemployment.min()
store_with_max_employment= max_unemployment.idxmax(), max_unemployment.max()
store_with_min_employment, store_with_max_employment
# Out:
# ((4, 3.879), (12, 14.313))

# %% [markdown]
# The result shows that the store with the lowest unemployment rate is Store 4 with 3.879%  and the store with the highest  unemployment rate is Store 12 with 14.313%.

# %%
Unemployment_by_store = df.groupby('Store')['Unemployment'].mean().reset_index()
min_unemployment_store = Unemployment_by_store.loc[Unemployment_by_store['Unemployment'].idxmin()]
max_unemployment_store = Unemployment_by_store.loc[Unemployment_by_store['Unemployment'].idxmax()]
print(f"Store with the lowest unemployment rate is:{min_unemployment_store['Store']} with the rate: {min_unemployment_store['Unemployment']}%")
print(f"Store with the highest unemployment rate is:{max_unemployment_store['Store']} with the rate: {max_unemployment_store['Unemployment']}%")
# Vizualization
plt.figure(figsize=(12,6))
sns.barplot(x='Store', y='Unemployment', data=Unemployment_by_store, palette = 'viridis')
plt.axhline(min_unemployment_store['Unemployment'],color='blue', linestyle='--', label = f"Lowest Unemployment:{min_unemployment_store['Store']}")
plt.axhline(max_unemployment_store['Unemployment'],color ='red', linestyle='--', label = f"Highest Unemployment:{max_unemployment_store['Store']}") 
plt.title('Average Unemployment Rate by Store')
plt.xlabel('Store')
plt.ylabel('Average Unemployment Rate')
plt.xticks(rotation=45) # Xoay nhãn trên trục X góc 45
plt.legend()
plt.show()
# Out:
# Store with the lowest unemployment rate is:23.0 with the rate: 4.796013986013985%
# Store with the highest unemployment rate is:12.0 with the rate: 13.116482517482517%

# %% [markdown]
# ### Is there any correlation between CPI and Weekly Sales? How is the correlation different when the Holiday Flag is 0 versus when the Holiday Flag is 1? ###

# %%
Corr_non_holiday = df[df['Holiday_Flag']==0][['CPI','Weekly_Sales']].corr()
Corr_hodiday= df[df['Holiday_Flag']== 1][['CPI', 'Weekly_Sales']].corr()
print('Correlation between CPI and Weekly Sales when the Holiday Flag is 0',Corr_non_holiday)
print('Correlation between CPI and Weekly Sales when the Holiday Flag is 1',Corr_hodiday)
# Out:
# Correlation between CPI and Weekly Sales when the Holiday Flag is 0                    CPI  Weekly_Sales
# CPI           1.000000     -0.071939
# Weekly_Sales -0.071939      1.000000
# Correlation between CPI and Weekly Sales when the Holiday Flag is 1                   CPI  Weekly_Sales
# CPI           1.00000      -0.08097
# Weekly_Sales -0.08097       1.00000

# %% [markdown]
# From the result above, we can see that the correlation between CPI and Weekly Sales when there are  Holidays and there are no  Holidays are both negative correlations with the similar values. This means that when CPI increses, Weekly sales tend to decrease and vice versa. When CPI increases, the average price rise, leading to inflation, meaning the cost of living is rising.
# As prices rise due to inflation, consumers' purchasing power diminishes. They may find that their income doesn't stretch as far, leading them to cut back on non-essential purchases or switch to cheaper alternatives. This reduction in consumer spending can lead to a decrease in weekly sales.

# %% [markdown]
# ### What conclusions can be drawn about fuel prices in this dataset?

# %%
#  the correlation between fuel price and weekly sales
corr_fuel_sales = df[['Fuel_Price','Weekly_Sales']].corr()
corr_fuel_sales
# Out:
#               Fuel_Price  Weekly_Sales
# Fuel_Price      1.000000      0.009515
# Weekly_Sales    0.009515      1.000000

# %%
sns.scatterplot(x='Fuel_Price', y='Weekly_Sales', data=df)
plt.title('Correlation between Fuel Price and Weekly Sales')
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')
# Out:
# Text(0, 0.5, 'Weekly Sales')

# %% [markdown]
# With a value of 0.009515, the relationship between fuel prices and weekly sales is almost non-existent or insignificant. This value indicates that fuel price fluctuations have no  significant influence or minimal impact on weekly sales.
# Possible causes:
# Fuel prices may not be the main factor influencing customers' purchasing decisions.
# Sales may depend on many other factors such as product price, promotions, seasonality, or other economic factors, and are not greatly affected by fuel prices.

# %%
# Correlation between fuel price and unemployment
corr_fuel_unemployment = df[['Fuel_Price', 'Unemployment']].corr()
corr_fuel_unemployment
# Out:
#               Fuel_Price  Unemployment
# Fuel_Price      1.000000     -0.035039
# Unemployment   -0.035039      1.000000

# %%
sns.scatterplot(x='Fuel_Price',y='Unemployment', data=df)
plt.title('Correlation between Fuel Price and Unemployment')
plt.xlabel('Fuel price')
plt.ylabel('Unemployment')
plt.show()

# %% [markdown]
# The correlation coefficient -0.035039 shows that in this data set, fuel prices do not have a strong or significant relationship with the unemployment rate. Other factors may play a more important role in determining the unemployment rate.

# %%
# Correlation between fuel price and CPI
corr_fuel_CPI = df[['Fuel_Price', 'CPI']].corr()
corr_fuel_CPI
# Out:
#             Fuel_Price       CPI
# Fuel_Price    1.000000 -0.170572
# CPI          -0.170572  1.000000

# %%
sns.scatterplot(x='Fuel_Price', y='CPI', data=data)
plt.title('Correlation between Fuel Price and CPI')
plt.xlabel('Fuel Price')
plt.ylabel('CPI')
plt.show()

# %% [markdown]
# The correlation coefficient -0.170572 shows that  fuel prices have a weak negative relationship with CPI. This means that when fuel prices increase, CPI tends to decrease, but this relationship is not strong enough to confirm that fuel prices are the main factor affecting CPI. Other factors in the economy may play a more important role in shaping CPI. This might be beacuse that the CPI reflects the prices of a basket of consumer goods and services, and fuel prices are a component of this basket of goods. However, fuel prices are only one of many factors affecting CPI.

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.667754     3.358620
# std      12.988182  5.643666e+05      0.255049    18.449806     0.459097
# min       1.000000  2.099862e+05      0.000000    -2.000000     2.470000
# 25%      12.000000  5.533501e+05      0.000000    47.500000     2.930000
# 50%      23.000000  9.607460e+05      0.000000    63.000000     3.440000
# 75%      34.000000  1.420159e+06      0.000000    75.000000     3.740000
# max      45.000000  3.818686e+06      1.000000   100.000000     4.470000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356709      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.617000      7.874000
# 75%     212.743500      8.622000
# max     227.233000     14.313000

# %%
corr = df[['Weekly_Sales','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment']].corr()
corr
# Out:
#               Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# Weekly_Sales      1.000000      0.036891    -0.063875    0.009515 -0.072634
# Holiday_Flag      0.036891      1.000000    -0.154892   -0.078021 -0.002162
# Temperature      -0.063875     -0.154892     1.000000    0.144583  0.177128
# Fuel_Price        0.009515     -0.078021     0.144583    1.000000 -0.170572
# CPI              -0.072634     -0.002162     0.177128   -0.170572  1.000000
# Unemployment     -0.106176      0.010960     0.101029   -0.035039 -0.302020
#
#               Unemployment
# Weekly_Sales     -0.106176
# Holiday_Flag      0.010960
# Temperature       0.101029
# Fuel_Price       -0.035039
# CPI              -0.302020
# Unemployment      1.000000

# %%
sns.heatmap(corr,annot=True)
plt.title('Crrelation Heatmap')
plt.show()

# %%
data = df[['Weekly_Sales','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment']]
sns.pairplot(data)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Key insight
# - Impact of Holidays on Sales
#   + Sales peaked around December 23–24, coinciding with Christmas Eve.
#   + Significant increases were also observed in late November, during Thanksgiving and Black Friday.
# → Major holidays have a strong positive impact on sales performance.
#
# - Unemployment Rate by Store
#   + Store 4 had the lowest unemployment rate: 3.879%
#   + Store 12 had the highest: 14.313%
# → Local economic conditions significantly influence consumers' purchasing power.
#
# - Correlation between CPI and Weekly Sales
#   + There is a negative correlation between the Consumer Price Index (CPI) and weekly sales, both during holidays and non-holidays.
#   + As CPI increases → average prices rise → inflation → sales tend to decline.
# → CPI is a key macroeconomic indicator that negatively affects consumer spending.

# %% [markdown]
# Conclusion and Recommendations
# - Conclusion
#   + Walmart sales are highly seasonal, with clear spikes during major holidays.
#   + Both CPI and unemployment rates have the potential to negatively impact sales.
#   + The data suggests focusing on optimizing sales campaigns during holiday periods to maximize revenue.
#
# - Recommendations
#   + Launch aggressive marketing campaigns during peak periods like Christmas and Black Friday.
#   + Closely monitor macroeconomic indicators such as CPI to adjust pricing and promotions accordingly.
#   + Invest more in areas with lower unemployment rates (e.g., Store 4) due to higher consumer spending potential.
